# %%
import numpy as np
from numpy.testing import assert_almost_equal

####
# Correct Number of groups 
####

# Gaussian 
def test_numgroups_gaus():
    y = np.random.random(100)
    x = np.random.random(100)
    id = range(1,101)
    model = "normal"
    ng =  np.random.randint(low=1,high=6,size=1)
    assert len(set(group_ltj(y, x, id, model, ng)[:,1])) == ng
 
# Logit 
def test_numgroups_logit():
    y = np.random.randint(2, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "logit"
    ng =  np.random.randint(low=1,high=6,size=1)
    assert len(set(group_ltj(y, x, id, model, ng)[:,1])) == ng

# ZIP 
def test_numgroups_zip():
    y = np.random.randint(20, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "zip"
    ng =  np.random.randint(low=1,high=6,size=1)
    assert len(set(group_ltj(y, x, id, model, ng)[:,1])) == ng
    
####
# Matching Subject id's  
####
# Gaussian 
def test_subjid_gaus():
    y = np.random.random(100)
    x = np.random.random(100)
    id = range(1,101)
    model = "normal"
    ng =  np.random.randint(low=1,high=6,size=1)
    assert set(group_ltj(y, x, id, model, ng)[:,0]) == id
 
# Logit 
def test_subjid_logit():
    y = np.random.randint(2, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "logit"
    ng =  np.random.randint(low=1,high=6,size=1)
    assert set(group_ltj(y, x, id, model, ng)[:,0]) == id
    
# ZIP 
def test_subjid_zip():
    y = np.random.randint(20, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "zip"
    ng =  np.random.randint(low=1,high=6,size=1)
    assert set(group_ltj(y, x, id, model, ng)[:,0]) == id
    

####
# Probabilites across  all groups for each id sum to 1
####
# Gaussian 
def test_sum_probs_gaus():
    y = np.random.random(100)
    x = np.random.random(100)
    id = range(1,101)
    model = "normal"
    ng =  np.random.randint(low=1,high=6,size=1)
    assert np.sum(data[data[:,0] == id][:,2])==1.0
    
# Logit 
def test_sum_probs_logit():
    y = np.random.randint(2, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "logit"
    ng =  np.random.randint(low=1,high=6,size=1)
    assert np.sum(data[data[:,0] == id][:,2])==1.0
    
def test_sum_probs_zip():
    y = np.random.randint(20, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "zip"
    ng =  np.random.randint(low=1,high=6,size=1)
    assert np.sum(data[data[:,0] == id][:,2])==1.0


####
# Positive probability tests
####
# Gaussian 
def test_posprobs_gaus_2groups():
    y = np.random.random(100)
    x = np.random.random(100)
    id = range(1,101)
    model = "normal"
    ng = 2
    assert group_ltj(y, x, id, model, ng)[:,2] >=0
    
def test_posprobs_gaus_3groups():
    y = np.random.random(100)
    x = np.random.random(100)
    id = range(1,101)
    model = "normal"
    ng = 3
    assert group_ltj(y, x, id, model, ng)[:,2] >=0
    
def test_posprobs_gaus_4groups():
    y = np.random.random(100)
    x = np.random.random(100)
    id = range(1,101)
    model = "normal"
    ng = 4
    assert group_ltj(y, x, id, model, ng)[:,2] >=0
    
def test_posprobs_gaus_5groups():
    y = np.random.random(100)
    x = np.random.random(100)
    id = range(1,101)
    model = "normal"
    ng = 5
    assert group_ltj(y, x, id, model, ng)[:,2] >=0
    
def test_posprobs_gaus_6groups():
    y = np.random.random(100)
    x = np.random.random(100)
    id = range(1,101)
    model = "normal"
    ng = 6
    assert group_ltj(y, x, id, model, ng)[:,2] >=0

# Logit 
def test_posprobs_logit_2groups():
    y = np.random.randint(2, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "logit"
    ng = 2
    assert group_ltj(y, x, id, model, ng)[:,2] >=0
    
def test_posprobs_logit_3groups():
    y = np.random.randint(2, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "logit"
    ng = 3
    assert group_ltj(y, x, id, model, ng)[:,2] >=0
    
def test_posprobs_logit_4groups():
    y = np.random.randint(2, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "logit"
    ng = 4
    assert group_ltj(y, x, id, model, ng)[:,2] >=0
    
def test_posprobs_logit_5groups():
    y = np.random.randint(2, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "logit"
    ng = 5
    assert group_ltj(y, x, id, model, ng)[:,2] >=0
    
def test_posprobs_logit_6groups():
    y = np.random.randint(2, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "logit"
    ng = 6
    assert group_ltj(y, x, id, model, ng)[:,2] >=0   

    
# ZIP
def test_posprobs_zip_2groups():
    y = np.random.randint(20, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "zip"
    ng = 2
    assert group_ltj(y, x, id, model, ng)[:,2] >=0
    
def test_posprobs_zip_3groups():
    y = np.random.randint(20, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "zip"
    ng = 3
    assert group_ltj(y, x, id, model, ng)[:,2] >=0
    
def test_posprobs_zip_4groups():
    y = np.random.randint(20, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "zip"
    ng = 4
    assert group_ltj(y, x, id, model, ng)[:,2] >=0
    
def test_posprobs_zip_5groups():
    y = np.random.randint(20, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "zip"
    ng = 5
    assert group_ltj(y, x, id, model, ng)[:,2] >=0
    
def test_posprobs_zip_6groups():
    y = np.random.randint(20, size=100)
    x = np.random.random(100)
    id = range(1,101)
    model = "zip"
    ng = 6
    assert group_ltj(y, x, id, model, ng)[:,2] >=0
